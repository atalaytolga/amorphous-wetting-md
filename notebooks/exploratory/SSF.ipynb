# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/group/ag_compstatphys/data/tolga/simulation'
file_name = 'slit_pore__production_D15_rho0.7_T1.00_20251015_163600.h5'

# %%
def read_positions(file_name):
    file_path = f'{data_path}/{file_name}'
    with h5py.File(file_path, 'r') as sim_data:
        positions = sim_data['particles/fluid/position/value'][:]
    return positions

# %%
pos = read_positions(file_name)
